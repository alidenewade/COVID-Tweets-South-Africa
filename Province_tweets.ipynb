# %%
import pandas as pd
import numpy as np
Days = [2,3,4,5,6,7,8,9]
days = np.arange(10,31)

Covid_1 = pd.read_csv (r'C:\Users\temok\Documents\Life depends on it\tweets_2021_06_01_covid.csv',keep_default_na=False,na_values=[""])
for d in Days:
    Covid = pd.read_csv (r'C:\Users\temok\Documents\Life depends on it\tweets_2021_06_0{}_covid.csv'.format(d),keep_default_na=False,na_values=[""])
    #print(Covid)
    Covid_1 = Covid_1.append(Covid)
for d in days:
    Covid = pd.read_csv (r'C:\Users\temok\Documents\Life depends on it\tweets_2021_06_{}_covid.csv'.format(d),keep_default_na=False,na_values=[""])
    #print(Covid)
    Covid_1 = Covid_1.append(Covid)
Days = [1,2,3,4]    
for d in Days:
    Covid = pd.read_csv (r'C:\Users\temok\Documents\Life depends on it\tweets_2021_07_0{}_covid.csv'.format(d),keep_default_na=False,na_values=[""])
    #print(Covid)
    Covid_1 = Covid_1.append(Covid)

# %%
Covid = Covid_1
#Vaccines =pd.read_json ('./Vaccines.json')
#Interven = pd.read_json('./Intervention.json')
Covid.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_1.csv')
Covid
# Out:
#      Unnamed: 0        username                    location  following  \
# 0             0    NjabuloSizwe  Johannesburg, South Africa        600
# 1             1          Jgove2                         NaN         15
# 2             2  Mbuyisabhunga6  Kempton Park, South Africa         62
# 3             3   steven_tshipa                   Jouberton          2
# 4             4   nomsachingowe   📍 Sekhukhune 🏡 Ha-Mulima        8072
# ..          ...             ...                         ...        ...
# 282         282   nobuhle_qwabz  Johannesburg, South Africa        761
# 283         283   ChangeAgentSA                South Africa       1080
# 284         284       nordienmn  Johannesburg, South Africa       3651
# 285         285     Nicky_TTimm   Johannesburg South Africa        705
# 286         286      BZ_Dlamini        Durban, South Africa      15807
#
#      followers  totaltweets                  tweetcreatedts  retweetcount  \
# ...

# %%
#Kwazulu Natal
frames = [Covid[Covid.location == "Durban, South Africa"],Covid[Covid.location == "Durban"],
          Covid[Covid.location == "Pietermaritzburg, South Africa"],Covid[Covid.location == "Pietermaritzburg"],
          Covid[Covid.location == "Newcastle, South Africa"],Covid[Covid.location == "Howick, South Africa"],
          Covid[Covid.location == "Newcastle"],Covid[Covid.location == "Ladysmith"],Covid[Covid.location == "Ladysmith, South Africa"],
          Covid[Covid.location == "Richards Bay, South Africa"],Covid[Covid.location == "Richard Bay"],
          Covid[Covid.location == "Howick, South Africa"],Covid[Covid.location == "Port Shepstone, South Africa"],
          Covid[Covid.location == "Umhlanga, South Africa"],Covid[Covid.location == "Umhlanga"],
          Covid[Covid.location == "Kokstad, South Africa"],
          Covid[Covid.location == "Empangeni, South Africa"],Covid[Covid.location == "Empangeni"],
          Covid[Covid.location == "Estcourt, South Africa"],Covid[Covid.location == "Ixopo, South Africa"],
          Covid[Covid.location == "Ulundi, South Africa"],
          Covid[Covid.location == "Vryheid"],Covid[Covid.location == "Vryheid, South Africa"],
          Covid[Covid.location == "Margate, South Africa"], Covid[Covid.location == "Scottburgh, South Africa"],
          Covid[Covid.location == "Dolphin Coast, South Africa"], Covid[Covid.location == "Pinetown, South Africa"],
          Covid[Covid.location == "Eshowe, South Africa"], Covid[Covid.location == "Amazimtoti, South Africa"],
          Covid[Covid.location == "Dundee, South Africa"],Covid[Covid.location == "Mtubatuba, South Africa"],
          Covid[Covid.location == "KwaDukuza, South Africa"], Covid[Covid.location == "Kloof, South Africa"],
          Covid[Covid.location == "KwaZulu Natal, South Africa"], Covid[Covid.location == "KwaZulu Natal"]]

result = pd.concat(frames)
result
# Out:
#     Unnamed: 0         username                 location  following  \
# 10          10            pedvr     Durban, South Africa        662
# 31          31      AndreRoodt4     Durban, South Africa         84
# 46          46       ThutontleJ     Durban, South Africa       4108
# 68          68         Tuliodna     Durban, South Africa        448
# 53          53            pedvr     Durban, South Africa        662
# ..         ...              ...                      ...        ...
# 11          11        Mlondi777   Pinetown, South Africa        890
# 21          21        Mlondi777   Pinetown, South Africa        890
# 5            5   mmatona_ntuane   Pinetown, South Africa       1069
# 52          52  Phumudz72230797  Mtubatuba, South Africa        320
# 72          72  Phumudz72230797  Mtubatuba, South Africa        320
#
#     followers  totaltweets                  tweetcreatedts  retweetcount  \
# 10        883        28093  Tue Jun 01 09:44:47 +0000 2021             1
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_KwaZulu_Natal_1.csv')

# %%
#Northern_Cape
frames = [Covid[Covid.location == "Kimberly, South Africa"],Covid[Covid.location == "Kimberly"],
          Covid[Covid.location == "Upington, South Africa"],Covid[Covid.location == "Upington"],
          Covid[Covid.location == "Springbok, South Africa"],Covid[Covid.location == "Kuruman, South Africa"],
          Covid[Covid.location == "Springbok"],
          Covid[Covid.location == "Kuruman"],Covid[Covid.location == "Kakamas, South Africa"],
          Covid[Covid.location == "Colesberg, South Africa"],Covid[Covid.location == "De Aar"],
          Covid[Covid.location == "De Aar, South Africa"],Covid[Covid.location == "Victoria West, South Africa"],
          Covid[Covid.location == "Sutherland, South Africa"],Covid[Covid.location == "Sutherland"],
          Covid[Covid.location == "Hanover, South Africa"],Covid[Covid.location == "Orania, South Africa"],
          Covid[Covid.location == "Orania"],Covid[Covid.location == "Postmasburg, South Africa"],
          Covid[Covid.location == "Warrenton, South Africa"],Covid[Covid.location == "Barkly West, South Africa"],
          Covid[Covid.location == "Jan Kemdorp, South Africa"],
          Covid[Covid.location == "Northern Cape, South Africa"],Covid[Covid.location == "Northern Cape"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username               location  following  followers  \
# 159         159  OlebogengLeser2  Kuruman, South Africa        753        407
# 14           14   Kgotla_mosiapo  Kuruman, South Africa       4951       2645
#
#      totaltweets                  tweetcreatedts  retweetcount  \
# 159          750  Tue Jun 29 04:45:14 +0000 2021             0
# 14          2174  Wed Jun 30 12:24:42 +0000 2021             1
#
#                                                   text hashtags
# 159  What happened to Covid 19 site at Nasrec my pe...       []
# 14   @METROFMSA\n#TLM\n@Leratokganyago\n\nIjoo, I b...  ['TLM']

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Northern_Cape_1.csv')

# %%
#Limpopo
frames = [Covid[Covid.location == "Polokwane, South Africa"],Covid[Covid.location == "Polokwane"],
          Covid[Covid.location == "Venda, South Africa"],Covid[Covid.location == "Venda"],
          Covid[Covid.location == "Giyane, South Africa"],Covid[Covid.location == "Tzaneen, South Africa"],
          Covid[Covid.location == "Tzaneen"],Covid[Covid.location == "Giyane"],
          Covid[Covid.location == "Mokopane, South Africa"],Covid[Covid.location == "Phalaborwa, South Africa"],
          Covid[Covid.location == "Phalaborwa"],Covid[Covid.location == "Modimolle, South Africa"],
          Covid[Covid.location == "Bela-Bela, South Africa"],Covid[Covid.location == "Bela Bela, South Africa"],
          Covid[Covid.location == "Musina"],Covid[Covid.location == "Musina, South Africa"],
          Covid[Covid.location == "Lephalale, South Africa"],Covid[Covid.location == "Louis Trichardt"],
          Covid[Covid.location == "Louis Trichardt, South Africa"],Covid[Covid.location == "Thohoyandou, South Africa"],
          Covid[Covid.location == "Thabazimbi, South Africa"],Covid[Covid.location == "Seshego, South Africa"],
          Covid[Covid.location == "Thulamela, South Africa"], Covid[Covid.location == "Lebowakgomo, South Africa"],
          Covid[Covid.location == "Mahwelereng, South Africa"], Covid[Covid.location == "Nkowankowa, South Africa"],
          Covid[Covid.location == "Limpopo, South Africa"], Covid[Covid.location == "Limpopo"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username                   location  following  \
# 78           78      Khazi_Rinae    Polokwane, South Africa        857
# 59           59        MeMeGuruu    Polokwane, South Africa       3426
# 108         108        MeMeGuruu    Polokwane, South Africa       3426
# 49           49      Khazi_Rinae    Polokwane, South Africa        857
# 72           72  Nkgadimaclinton    Polokwane, South Africa       1350
# ..          ...              ...                        ...        ...
# 151         151     Molokela_sam    Lephalale, South Africa        312
# 102         102         05Danzel    Lephalale, South Africa       3319
# 36           36         TIMaledi  Mahwelereng, South Africa       2441
# 179         179         TIMaledi  Mahwelereng, South Africa       2474
# 89           89         TIMaledi  Mahwelereng, South Africa       2487
#
#      followers  totaltweets                  tweetcreatedts  retweetcount  \
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Limpopo_1.csv')

# %%
#North West
frames = [Covid[Covid.location == "Mahikeng, South Africa"],Covid[Covid.location == "Mahikeng"],
          Covid[Covid.location == "Rustenburg, South Africa"],Covid[Covid.location == "Rustenburg"],
          Covid[Covid.location == "Potchefstroom, South Africa"],Covid[Covid.location == "Brits, South Africa"],
          Covid[Covid.location == "Pochefstroom"],Covid[Covid.location == "Vryburg"],
          Covid[Covid.location == "Vryburg, South Africa"],Covid[Covid.location == "Hartbeesport, South Africa"],
          Covid[Covid.location == "Hartbeesport"],Covid[Covid.location == "Lichtenburg, South Africa"],
          Covid[Covid.location == "Mmabatho, South Africa"],Covid[Covid.location == "Zeerust, South Africa"],
          Covid[Covid.location == "Zeerust"],Covid[Covid.location == "Stilfontein, South Africa"],
          Covid[Covid.location == "Mogwase, South Africa"],Covid[Covid.location == "Ganyesa"],
          Covid[Covid.location == "Ganyesa, South Africa"],Covid[Covid.location == "Mathibestad, South Africa"],
          Covid[Covid.location == "Mmakau, South Africa"],Covid[Covid.location == "Mmakau"],
          Covid[Covid.location == "Koster, South Africa"], Covid[Covid.location == "North West, South Africa"],
          Covid[Covid.location == "North West"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username                     location  following  \
# 153         153          MHKFMSA                     Mahikeng         44
# 69           69      Kvsh_Molton     Rustenburg, South Africa       9162
# 72           72      Botshelo_SA     Rustenburg, South Africa       1444
# 3             3      MamaBokgabo     Rustenburg, South Africa        709
# 40           40      _TMolebatsi     Rustenburg, South Africa       1757
# 68           68     VilakaziMark     Rustenburg, South Africa       2449
# 20           20      Botshelo_SA     Rustenburg, South Africa       1473
# 30           30        TEECRUSH1     Rustenburg, South Africa       1254
# 82           82      skyjuice_za     Rustenburg, South Africa       3812
# 9             9     MngadiZinhle     Rustenburg, South Africa       1417
# 80           80      _TMolebatsi     Rustenburg, South Africa       1757
# 173         173   Paledi65173967     Rustenburg, South Africa       1813
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_North_West_1.csv')

# %%
#Mpumalanga
frames = [Covid[Covid.location == "Mbombela, South Africa"],Covid[Covid.location == "Mbombela"],
          Covid[Covid.location == "Secunda, South Africa"],Covid[Covid.location == "Secunda"],
          Covid[Covid.location == "Matsulu, South Africa"],Covid[Covid.location == "Lydenburg, South Africa"],
          Covid[Covid.location == "Lydenburg"],Covid[Covid.location == "Ermelo"],
          Covid[Covid.location == "Ermelo, South Africa"],Covid[Covid.location == "Barberton, South Africa"],
          Covid[Covid.location == "Barberton"],Covid[Covid.location == "Middelburg, South Africa"],
          Covid[Covid.location == "Bethal, South Africa"],Covid[Covid.location == "White River, South Africa"],
          Covid[Covid.location == "Middelburg"],Covid[Covid.location == "Sabie, South Africa"],
          Covid[Covid.location == "Volksrust, South Africa"],Covid[Covid.location == "Volksrust"],
          Covid[Covid.location == "Standerton, South Africa"],Covid[Covid.location == "Piet Retief, South Africa"],
          Covid[Covid.location == "Delmas, South Africa"],Covid[Covid.location == "KwaMhlanga"],
          Covid[Covid.location == "KwaMhlanga, South Africa"], Covid[Covid.location == "Siyabuswa, South Africa"],
          Covid[Covid.location == "Carolina, South Africa"],Covid[Covid.location == "Breyten, South Africa"],
          Covid[Covid.location == "Embalenhle, South Africa"], Covid[Covid.location == "Embalenhle"],
          Covid[Covid.location == "Mpumalanga, South Africa"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username                  location  following  \
# 12           12     khoza_bonnie    Mbombela, South Africa       3404
# 26           26    MissSophie_SA    Mbombela, South Africa        344
# 25           25           kuhnl1     Secunda, South Africa        894
# 25           25           kuhnl1     Secunda, South Africa        894
# 26           26           kuhnl1     Secunda, South Africa        895
# 166         166           kuhnl1     Secunda, South Africa        894
# 40           40  Glorian12629854  Embalenhle, South Africa        367
# 40           40  Glorian12629854  Embalenhle, South Africa        367
# 29           29  Glorian12629854  Embalenhle, South Africa        421
# 41           41  Glorian12629854  Embalenhle, South Africa        421
# 38           38  Glorian12629854  Embalenhle, South Africa        430
# 83           83  Glorian12629854  Embalenhle, South Africa        430
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Mpumalanga_1.csv')

# %%
#Free State
frames = [Covid[Covid.location == "Bloemfontein, South Africa"],Covid[Covid.location == "Bloemfontein"],
          Covid[Covid.location == "Welkom, South Africa"],Covid[Covid.location == "Welkom"],
          Covid[Covid.location == "Reitz, South Africa"],Covid[Covid.location == "QwaQwa, South Africa"],
          Covid[Covid.location == "QwaQwa"],Covid[Covid.location == "Phuthaditjhaba"],
          Covid[Covid.location == "Phuthaditjhaba, South Africa"],Covid[Covid.location == "Mangaung, South Africa"],
          Covid[Covid.location == "Mangaung"],Covid[Covid.location == "Ficksburg, South Africa"],
          Covid[Covid.location == "Bothaville, South Africa"],Covid[Covid.location == "Sasolburg, South Africa"],
          Covid[Covid.location == "Sasolburg"],Covid[Covid.location == "Parys, South Africa"],
          Covid[Covid.location == "Botshabelo, South Africa"],Covid[Covid.location == "Kroonstad"],
          Covid[Covid.location == "Kroonstad, South Africa"],Covid[Covid.location == "Odendaalsrus, South Africa"],
          Covid[Covid.location == "Fouriesburg, South Africa"],Covid[Covid.location == "Virginia"],
          Covid[Covid.location == "Virginia, South Africa"], Covid[Covid.location == "Deneysville, South Africa"],
          Covid[Covid.location == "Thaba Nchu, South Africa"],Covid[Covid.location == "Heilbron, South Africa"],
          Covid[Covid.location == "Clocolan, South Africa"], Covid[Covid.location == "Koffiefontein, South Africa"],
          Covid[Covid.location == "Frankfor, South Africa"], Covid[Covid.location == "Vredefort, South Africa"],
          Covid[Covid.location == "Zastron, South Africa"], Covid[Covid.location == "Free State, South Africa"],
          Covid[Covid.location == "Free State"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username                      location  following  \
# 22           22    KeneuoeLerato    Bloemfontein, South Africa        405
# 59           59       SanchezSua    Bloemfontein, South Africa        968
# 56           56       Lindani__G    Bloemfontein, South Africa        814
# 64           64     Lebotha_kai1    Bloemfontein, South Africa       5000
# 84           84  MphoKho82637424    Bloemfontein, South Africa       2568
# 97           97    TebohoLetuka3    Bloemfontein, South Africa        196
# 214         214     Teboho_Ranks    Bloemfontein, South Africa       1200
# 49           49  CalvinTouchdown    Bloemfontein, South Africa       2081
# 80           80    masegomfoloe_    Bloemfontein, South Africa       5032
# 163         163     Teboho_Ranks    Bloemfontein, South Africa       1199
# 79           79  Michele_Phaahla    Bloemfontein, South Africa       2158
# 14           14     SerameMmatli    Bloemfontein, South Africa        159
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Free_state_1.csv')

# %%
#Kwazulu Natal
frames = [Covid[Covid.location == "Durban, South Africa"],Covid[Covid.location == "Durban"],
          Covid[Covid.location == "Pietermaritzburg, South Africa"],Covid[Covid.location == "Pietermaritzburg"],
          Covid[Covid.location == "Newcastle, South Africa"],Covid[Covid.location == "Howick, South Africa"],
          Covid[Covid.location == "Newcastle"],Covid[Covid.location == "Ladysmith"],Covid[Covid.location == "Ladysmith, South Africa"],
          Covid[Covid.location == "Richards Bay, South Africa"],Covid[Covid.location == "Richard Bay"],
          Covid[Covid.location == "Howick, South Africa"],Covid[Covid.location == "Port Shepstone, South Africa"],
          Covid[Covid.location == "Umhlanga, South Africa"],Covid[Covid.location == "Umhlanga"],
          Covid[Covid.location == "Kokstad, South Africa"],Covid[Covid.location == "Empangeni, South Africa"],
          Covid[Covid.location == "Empangeni"],Covid[Covid.location == "Estcourt, South Africa"],
          Covid[Covid.location == "Ixopo, South Africa"],Covid[Covid.location == "Ulundi, South Africa"],
          Covid[Covid.location == "Vryheid"],Covid[Covid.location == "Vryheid, South Africa"],
          Covid[Covid.location == "Margate, South Africa"], Covid[Covid.location == "Scottburgh, South Africa"],
          Covid[Covid.location == "Dolphin Coast, South Africa"], Covid[Covid.location == "Pinetown, South Africa"],
          Covid[Covid.location == "Eshowe, South Africa"], Covid[Covid.location == "Amazimtoti, South Africa"],
          Covid[Covid.location == "Dundee, South Africa"],Covid[Covid.location == "Mtubatuba, South Africa"],
          Covid[Covid.location == "KwaDukuza, South Africa"], Covid[Covid.location == "Kloof, South Africa"],
          Covid[Covid.location == "KwaZulu Natal, South Africa"], Covid[Covid.location == "KwaZulu Natal"]]

result = pd.concat(frames)
result
# Out:
#     Unnamed: 0         username                 location  following  \
# 10          10            pedvr     Durban, South Africa        662
# 31          31      AndreRoodt4     Durban, South Africa         84
# 46          46       ThutontleJ     Durban, South Africa       4108
# 68          68         Tuliodna     Durban, South Africa        448
# 53          53            pedvr     Durban, South Africa        662
# ..         ...              ...                      ...        ...
# 11          11        Mlondi777   Pinetown, South Africa        890
# 21          21        Mlondi777   Pinetown, South Africa        890
# 5            5   mmatona_ntuane   Pinetown, South Africa       1069
# 52          52  Phumudz72230797  Mtubatuba, South Africa        320
# 72          72  Phumudz72230797  Mtubatuba, South Africa        320
#
#     followers  totaltweets                  tweetcreatedts  retweetcount  \
# 10        883        28093  Tue Jun 01 09:44:47 +0000 2021             1
# ...

# %%
#Eastern_Cape
frames = [Covid[Covid.location == "Port Elizabeth, South Africa"],Covid[Covid.location == "Port Elizabeth"],
          Covid[Covid.location == "East London, South Africa"],Covid[Covid.location == "East London"],
          Covid[Covid.location == "Grahamstown, South Africa"],Covid[Covid.location == "Kariega, South Africa"],
          Covid[Covid.location == "Grahamstown"],Covid[Covid.location == "Kariega"],
          Covid[Covid.location == "Queenstown, South Africa"],Covid[Covid.location == "Port Alfred, South Africa"],
          Covid[Covid.location == "Port Alfred"],Covid[Covid.location == "Jeffrey Bay, South Africa"],
          Covid[Covid.location == "Jeffrey Bay"],Covid[Covid.location == "Butterworth, South Africa"],
          Covid[Covid.location == "Butterworth"],Covid[Covid.location == "Gqeberha, South Africa"],
          Covid[Covid.location == "Gqeberha"],Covid[Covid.location == "Eastern Cape, South Africa"],
          Covid[Covid.location == "Eastern Cape"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0       username                      location  following  \
# 73           73  _officialMoss  Port Elizabeth, South Africa       4580
# 91           91      ColeWwrld  Port Elizabeth, South Africa        248
# 47           47      ColeWwrld  Port Elizabeth, South Africa        248
# 47           47      ColeWwrld  Port Elizabeth, South Africa        248
# 7             7       Mbasa_EC  Port Elizabeth, South Africa        415
# ..          ...            ...                           ...        ...
# 199         199       sosospay                  Eastern Cape      14926
# 81           81       sosospay                  Eastern Cape      14925
# 96           96        SisaSne                  Eastern Cape       3476
# 127         127       sosospay                  Eastern Cape      14924
# 168         168       sosospay                  Eastern Cape      14924
#
#      followers  totaltweets                  tweetcreatedts  retweetcount  \
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Eastern_Cape_1.csv')

# %%
#Western_Cape
frames = [Covid[Covid.location == "Cape Town, South Africa"],Covid[Covid.location == "Cape Town"],
          Covid[Covid.location == "Stellenbosch, South Africa"],Covid[Covid.location == "Stellenbosch"],
          Covid[Covid.location == "Mossel Bay, South Africa"],Covid[Covid.location == "Mossel Bay"],
          Covid[Covid.location == "Hermanus"],Covid[Covid.location == "Paarl"],
          Covid[Covid.location == "Paarl, South Africa"],Covid[Covid.location == "George, South Africa"],
          Covid[Covid.location == "George"],Covid[Covid.location == "Bellville, South Africa"],
          Covid[Covid.location == "Bellville"],Covid[Covid.location == "Somerset West, South Africa"],
          Covid[Covid.location == "Somerset West"],Covid[Covid.location == "Western Cape, South Africa"],
          Covid[Covid.location == "Western Cape"]]

result = pd.concat(frames)
result
# Out:
#      Unnamed: 0         username                     location  following  \
# 5             5   brendancommins      Cape Town, South Africa       1949
# 36           36         Gay22Jay      Cape Town, South Africa        355
# 43           43  jason_penrose23      Cape Town, South Africa        153
# 4             4       NotAmanda_      Cape Town, South Africa        356
# 10           10         Gawiesnr      Cape Town, South Africa      17964
# ..          ...              ...                          ...        ...
# 119         119       DryEtienne  Somerset West, South Africa       1862
# 32           32    GideonMeiring  Somerset West, South Africa        260
# 243         243       DryEtienne  Somerset West, South Africa       1872
# 57           57          aneldev                 Western Cape        957
# 89           89          aneldev                 Western Cape        957
#
#      followers  totaltweets                  tweetcreatedts  retweetcount  \
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Western_Cape_1.csv')

# %%
#Gauteng
frames = [Covid[Covid.location == "Pretoria, South Africa"],Covid[Covid.location == "Pretoria"],
          Covid[Covid.location == "Johannesburg, South Africa"],Covid[Covid.location == "Johannesburg"],
          Covid[Covid.location == "Midrand, South Africa"],Covid[Covid.location == "Midrand"],
          Covid[Covid.location == "Sandton"],Covid[Covid.location == "Tshwane"],
          Covid[Covid.location == "Soweto, South Africa"],Covid[Covid.location == "Alberton, South Africa"],
          Covid[Covid.location == "PTA"],Covid[Covid.location == "Centurion, South Africa"],
          Covid[Covid.location == "Brakpan"],Covid[Covid.location == "Brakpan, South Africa"],
          Covid[Covid.location == "Wonderboom"],Covid[Covid.location == "Vanderbijlpark, South Africa"],
          Covid[Covid.location == "Nigel, South Africa"],Covid[Covid.location == "Roodepoort, South Africa"],
          Covid[Covid.location == "Vereeniging, South Africa"],Covid[Covid.location == "Krugersdorp, South Africa"],
          Covid[Covid.location == "Randfontein, South Africa"]]


result = pd.concat(frames)
result
# Out:
#      Unnamed: 0       username                   location  following  \
# 14           14  Mavuku_Jnr012     Pretoria, South Africa        339
# 49           49   mcCaillou_10     Pretoria, South Africa       4549
# 52           52   CalvinPhiri8     Pretoria, South Africa       1389
# 56           56  HealthTshwane     Pretoria, South Africa        173
# 6             6   CoachThulane     Pretoria, South Africa        714
# ..          ...            ...                        ...        ...
# 64           64  InInitiatives  Vereeniging, South Africa        388
# 155         155  InInitiatives  Vereeniging, South Africa        388
# 26           26    stickyflava  Krugersdorp, South Africa       3178
# 23           23   JohnnyNesh_M  Krugersdorp, South Africa        427
# 21           21    georgefiddy  Randfontein, South Africa       3500
#
#      followers  totaltweets                  tweetcreatedts  retweetcount  \
# ...

# %%
result.to_csv(r'C:\Users\temok\Documents\Life depends on it\Wordcloud_V2\Wordcloud_V2\tweets_covid_Gauteng_1.csv')
